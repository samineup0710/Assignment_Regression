# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data_columns = concrete_data.columns

# %%
X = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
Y = concrete_data['Strength'] # Strength column

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
len(X_train)
# Out:
# 721

# %%
len(Y_test)
# Out:
# 309

# %%
X.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
X_train.describe()
# Out:
#            Cement  Blast Furnace Slag     Fly Ash       Water  \
# count  721.000000          721.000000  721.000000  721.000000
# mean   280.382386           72.237587   55.618169  180.983218
# std    103.146474           86.599063   63.973422   21.072045
# min    102.000000            0.000000    0.000000  121.800000
# 25%    194.700000            0.000000    0.000000  165.600000
# 50%    266.000000           20.000000    0.000000  184.400000
# 75%    350.000000          141.300000  118.300000  192.000000
# max    540.000000          359.400000  200.100000  247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate         Age
# count        721.000000        721.000000      721.000000  721.000000
# mean           6.274619        974.377947      775.535229   42.249653
# std            5.912198         77.631518       80.117433   56.980638
# min            0.000000        801.000000      594.000000    1.000000
# ...

# %%
Y.describe()
# Out:
# count    1030.000000
# mean       35.817961
# std        16.705742
# min         2.330000
# 25%        23.710000
# 50%        34.445000
# 75%        46.135000
# max        82.600000
# Name: Strength, dtype: float64

# %%
predictors_train_norm = ((X_train - X_train.mean())/X_train.std())
predictors_test_norm = ((X_test - X_test.mean())/X_test.std())

# %%
target_train_norm = ((Y_train - Y_train.mean())/Y_train.std())
target_test_norm = ((Y_test - Y_test.mean())/Y_test.std())

# %%
predictors_train_norm
# Out:
#        Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 587 -0.408956            0.999577 -0.869395  0.223841         -1.061300
# 617 -0.255776           -0.834161 -0.869395  0.807552         -1.061300
# 471  1.605655           -0.557022  0.365493 -0.900872          0.900745
# 522  0.035073           -0.660949  1.334645 -0.094116         -0.131020
# 819  2.371556           -0.834161 -0.869395  0.380446         -1.061300
# ..        ...                 ...       ...       ...               ...
# 474  1.605655           -0.557022  0.365493 -0.900872          0.680860
# 160  0.797096            1.348310 -0.869395 -0.763249          0.900745
# 867 -1.108932            2.168181 -0.869395  0.095709          1.137543
# 143  0.917313            0.248991 -0.869395 -2.580823          2.896618
# 275 -0.280983           -0.834161  0.979811  0.356718         -0.080278
#
#      Coarse Aggregate  Fine Aggregate       Age
# 587          0.853031       -0.514685 -0.250079
# ...

# %%
target_train_norm
# Out:
#         Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1     2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3     0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4    -0.790075            0.678079 -0.846733  0.488555         -1.038638
# ...        ...                 ...       ...       ...               ...
# 1025 -0.045623            0.487998  0.564271 -0.092126          0.451190
# 1026  0.392628           -0.856472  0.959602  0.675872          0.702285
# 1027 -1.269472            0.759210  0.850222  0.521336         -0.017520
# 1028 -1.168042            1.307430 -0.846733 -0.279443          0.852942
# 1029 -0.193939            0.308349  0.376762  0.891286          0.400971
#
#       Coarse Aggregate  Fine Aggregate       Age
# ...

# %%
target_test_norm
# Out:
# 995   -0.502699
# 372    0.047860
# 930   -0.318988
# 108    0.612197
# 586   -1.257062
#          ...
# 737   -1.084833
# 478    0.894078
# 136    2.185222
# 167    2.167425
# 330    0.332038
# Name: Strength, Length: 309, dtype: float64

# %%
n_cols = predictors_norm.shape[1]

# %%
n_cols
# Out:
# 8

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import tensorflow as tf
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
def regression_model():
    model =keras.Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model
model = regression_model()
model.fit(predictors_train_norm, target_train_norm, validation_split=0.3, epochs =50, verbose=1)
# Out:
# Train on 504 samples, validate on 217 samples
# Epoch 1/50
# 504/504 [==============================] - 3s 5ms/step - loss: 1.9941 - val_loss: 1.6552
# Epoch 2/50
# 504/504 [==============================] - 1s 1ms/step - loss: 1.6777 - val_loss: 1.4291
# Epoch 3/50
# 504/504 [==============================] - 1s 1ms/step - loss: 1.4529 - val_loss: 1.2561
# Epoch 4/50
# 504/504 [==============================] - 0s 791us/step - loss: 1.2833 - val_loss: 1.1253
# Epoch 5/50
# 504/504 [==============================] - 1s 1ms/step - loss: 1.1550 - val_loss: 1.0246
# Epoch 6/50
# 504/504 [==============================] - 1s 1ms/step - loss: 1.0592 - val_loss: 0.9432
# Epoch 7/50
# 504/504 [==============================] - 1s 995us/step - loss: 0.9796 - val_loss: 0.8742
# Epoch 8/50
# 504/504 [==============================] - 1s 1ms/step - loss: 0.9133 - val_loss: 0.8134
# Epoch 9/50
# 504/504 [==============================] - 0s 874us/step - loss: 0.8548 - val_loss: 0.7583
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# ...
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn import metrics
import numpy as np
target_pred = model.predict(predictors_test_norm)
mserrB = metrics.mean_squared_error(target_test_norm, target_pred)
r2_scoresB = metrics.r2_scores = metrics.r2_score(target_test_norm, target_pred)
print('mserrA: {:.2f}'.format(mserrB))
print('mse_StdDev: {:.2f}'.format(r2_scoresB))
print('R^2_Mean: {:.2f}'.format(np.mean(r2_scoresB)))
print('R^2_StdDev: {:.2f}'.format(np.std(r2_scoresB)))
# Out:
# mserrA: 0.29
# mse_StdDev: 0.71
# R^2_Mean: 0.71
# R^2_StdDev: 0.00
